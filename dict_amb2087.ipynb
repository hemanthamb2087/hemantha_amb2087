# %%
cgpa={1:7.8,2:9.1,3:8.3}
print(cgpa)
print(type(cgpa))
print(len(cgpa))
# Out:
# {1: 7.8, 2: 9.1, 3: 8.3}
# <class 'dict'>
# 3

# %%
cgpa={1:7.8,2:9.1,3:8.3}
print("CGPA of 1 is ",cgpa[1])
print("CGPA of 2 is ",cgpa[2])
print("CGPA of 3 is ",cgpa[3])
# Out:
# CGPA of 1 is  7.8
# CGPA of 2 is  9.1
# CGPA of 3 is  8.3

# %%
cgpa={1:7.8,2:9.1,3:8.3}
for i in cgpa:
  print("CGPA of",i,"is\n",cgpa[i])
# Out:
# CGPA of 1 is
#  7.8
# CGPA of 2 is
#  9.1
# CGPA of 3 is
#  8.3

# %%
cgpa={1:7.8,2:9.1,3:8.3}
print(list(cgpa.keys()))
print(cgpa.values())
print(cgpa.items())
# Out:
# [1, 2, 3]
# dict_values([7.8, 9.1, 8.3])
# dict_items([(1, 7.8), (2, 9.1), (3, 8.3)])

# %%
cgpa={1:7.8,2:9.1,3:8.3}
cgpa[4]=6.5
print(cgpa)
cgpa[5]=6.5
print(cgpa)
cgpa[5]=3.5
print(cgpa)
# Out:
# {1: 7.8, 2: 9.1, 3: 8.3, 4: 6.5}
# {1: 7.8, 2: 9.1, 3: 8.3, 4: 6.5, 5: 6.5}
# {1: 7.8, 2: 9.1, 3: 8.3, 4: 6.5, 5: 3.5}

# %%
cgpa={1:7.8,2:9.1,3:8.3}
s=0
for i in cgpa:
  s=s+cgpa[i]
print("the total cgpa is",s)
print("the average cgpa is",s/len(cgpa))
# Out:
# the total cgpa is 25.2
# the average cgpa is 8.4

# %%
cgpa={1:7.8,2:9.1,3:8.3}
print("sum of the values is",sum(cgpa.values()))
print("average of the values is",sum(cgpa.values())/len(cgpa))
# Out:
# sum of the values is 25.2
# average of the values is 8.0

# %%
cgpa={1:7.8,2:9.1,3:8.3}
y=max(cgpa.values())
print("The maximum CGPA among the dictionary is",y)
z=min(cgpa.values())
# Out:
# The maximum CGPA among the dictionary is 9.1

# %%
cgpa={1:7.8,2:9.1,3:8.3}
keylist=list(cgpa.keys())
keyvalues=list(cgpa.values())
minvalue=min(cgpa.values())
print(keylist[keyvalues.index(minvalue)])
print(minvalue,"key=",keylist[keyvalues.index(minvalue)])
# Out:
# 1
# 7.8 key= 1

# %%
cgpa={1:7.8,2:9.1,3:8.3}
print("is 2 present in ",2 in cgpa.keys())
print("is 7.8 present in ",7.8 in cgpa.values())
# Out:
# is 2 present in  True
# is 7.8 present in  True

# %%
cgpa={1:7.8,2:9.1,3:8.3}
cgpa1={4:6.7,2:8.7}
cgpa1.update(cgpa)
print(cgpa1)
# Out:
# {4: 6.7, 2: 9.1, 1: 7.8, 3: 8.3}
