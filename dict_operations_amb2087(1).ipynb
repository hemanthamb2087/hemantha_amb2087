# %%
c={"Rice":120, "Wheat":85, "Maize":60}
print("The number of crops cultivated by the farmer is",len(c))
# Out:
# The number of crops cultivated by the farmer is 3

# %%
c={"Rice":120, "Wheat":85, "Maize":60}
print("The yield of wheat is",c["Wheat"])
print("The yield of wheat is",c.get("Wheat"))
# Out:
# The yield of wheat is 85
# The yield of wheat is 85

# %%
c={"Rice":120, "Wheat":85, "Maize":60}
c["Pulses"]=45
print(c)
# Out:
# {'Rice': 120, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
c["Rice"]=130
print(c)
# Out:
# {'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}

# %%
print("The list of crops grown by the farmer are:\n",list(c.keys()))
# Out:
# The list of crops grown by the farmer are:
#  ['Rice', 'Wheat', 'Maize', 'Pulses']

# %%
print("The yield of all crops are:\n",list(c.values()))
# Out:
# The yield of all crops are:
#  [130, 85, 60, 45]

# %%
if "Jowar" in c:
  print(c["Jowar"])
else:
  print("Jowar is not cultivated")
# Out:
# Jowar is not cultivated

# %%
print("Is sugarcane cultivated?\n","sugarcane" in c)
# Out:
# Is sugarcane cultivated?
#  False

# %%
c={'Rice': 130, 'Wheat': 85, 'Maize': 60, 'Pulses': 45}
c["Wheat"]=c["Wheat"]+10
print(c)
# Out:
# {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
s=0
for i in c:
  s=s+c[i]
print("The total yield of all crops is",s)
# Out:
# The total yield of all crops is 330

# %%
print("The total yield of all crops is",sum(c.values()))
# Out:
# The total yield of all crops is 330

# %%
c={'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}
for i in c:
  print(i,":",c[i])
for i,j in c.items():
  print(i,":",j)
for i in zip(c.keys(),c.values()):
 print(i)
# Out:
# Rice : 130
# Wheat : 95
# Maize : 60
# Pulses : 45
# Rice : 130
# Wheat : 95
# Maize : 60
# Pulses : 45
# ('Rice', 130)
# ('Wheat', 95)
# ('Maize', 60)
# ('Pulses', 45)

# %%
b=c.copy()
print(b)
# Out:
# {'Rice': 130, 'Wheat': 95, 'Maize': 60, 'Pulses': 45}

# %%
b.clear()
print(b)
# Out:
# {}

# %%
t=("Pratham","Sharma",3.14,4)       #TUPLE DATATYPE
print(t)
print("Number of elements is",len(t))
print("Type of datatype is",type(t))
# Out:
# ('Pratham', 'Sharma', 3.14, 4)
# Number of elements is 4
# Type of datatype is <class 'tuple'>

# %%
t=("Pratham","Sharma",3.14,4)
i=0
while i<len(t):
  print(t[i])
  i=i+1
# Out:
# Pratham
# Sharma
# 3.14
# 4

# %%
T=(3,6,9,12,5,3,2)
print(T[1])
print(T[1:4])
print(T[1:6:2])
print(T[-1])
print(T[-4:-1])
print(T[-6:-1:2])
print(T[::-1])
print(T[::1])
print(T[::-2])
print(T[-3:-6])
# Out:
# 6
# (6, 9, 12)
# (6, 12, 3)
# 2
# (12, 5, 3)
# (6, 12, 3)
# (2, 3, 5, 12, 9, 6, 3)
# (3, 6, 9, 12, 5, 3, 2)
# (2, 5, 9, 3)
# ()

# %%
T[2]=10
print(T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-170025300.py in <cell line: 0>()
# ----> 1 T[2]=10
#       2 print(T)
#
# TypeError: 'tuple' object does not support item assignment

# %%
T.insert(2,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1099910549.py in <cell line: 0>()
# ----> 1 T.insert(2,10)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
T.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-301955170.py in <cell line: 0>()
# ----> 1 T.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T.add(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4067787728.py in <cell line: 0>()
# ----> 1 T.add(1)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
T1=list(T)                #To add or alter a tuple first convert it into a list and make changes and convert it back to a tuple
T1.append(10)
T=tuple(T1)
print(T)
# Out:
# (3, 6, 9, 12, 5, 3, 2, 10)

# %%
T2=list(T)
T2.insert(3,4)
T=tuple(T2)
print(T)
# Out:
# (3, 6, 9, 4, 12, 5, 3, 2, 10)

# %%
print(sum(T))
print(sum(T)/len(T))
# Out:
# 54
# 6.0

# %%
print(max(T))
print(min(T))
print(12 in T)
# Out:
# 12
# 2
# True

# %%
Tu=(1,2,3,4,5,6)
Tup=(4,5,6,7,8,8)
Tupl=(9,8,7,6,5,4)
t=Tu+Tup+Tupl
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 4, 5, 6, 7, 8, 8, 9, 8, 7, 6, 5, 4)

# %%
t1=Tu[1:7] + Tup[2:6]
print(t1)
# Out:
# (2, 3, 4, 5, 6, 6, 7, 8, 8)

# %%
print(T.index(9))
print(T.count(3))
# Out:
# 2
# 2

# %%
l=[1,2,3,4]                               #Memory address does not change as it is mutable
print(id(l))
l.append(5)
print(id(l))
l1=l
l2=l.copy()
print(id(l1))
print(id(l2))
# Out:
# 137085475109120
# 137085475109120
# 137085475109120
# 137085477378048

# %%
d={1:"P",2:"R",3:"A",4:"T",5:"H",6:"A",7:"M"}
print(id(d))
d[8]="M"
print(id(d))
# Out:
# 137085477089408
# 137085477089408

# %%
s={6,4,7,8,3,23,2}
print(id(s))
s.add(11)
print(id(s))
# Out:
# 137085476099840
# 137085476099840

# %%
st="GKVK"
print(id(st))
st=st="Uni"
print(id(st))
# Out:
# 137085483664032
# 137085487516480

# %%
st[0]="K"
print(st)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3084256801.py in <cell line: 0>()
# ----> 1 st[0]="K"
#       2 print(st)
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))
print(id(z))
x=x+20
print(id(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2233779122.py in <cell line: 0>()
#       1 x=10
#       2 y=x
# ----> 3 z=x.copy()
#       4 print(id(x))
#       5 print(id(y))
#
# AttributeError: 'int' object has no attribute 'copy'

# %%
tt=(21,13,78,54,16,79)
print(id(tt))
TT=list(tt)
TT.append(77)
tt=tuple(TT)
print(id(tt))
# Out:
# 137085476338176
# 137085474620896
