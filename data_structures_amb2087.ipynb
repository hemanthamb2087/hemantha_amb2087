# %%
for i in range(1,101,4):
    print(i)
# Out:
# 1
# 5
# 9
# 13
# 17
# 21
# 25
# 29
# 33
# 37
# 41
# 45
# 49
# 53
# 57
# 61
# 65
# 69
# 73
# 77
# 81
# 85
# 89
# 93
# 97

# %%
x=[10,30,50]
for i in x:
  print(i)
# Out:
# 10
# 30
# 50

# %%
x=[1,10,20,30,40,50,60,70,80,90]
for i in x:
   print(i)
# Out:
# 1
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
a=10.9
print(type(a))
# Out:
# <class 'float'>

# %%
a="heramba"
print(type(a))
# Out:
# <class 'str'>

# %%
a=[10,20,30]
print(type(a))
# Out:
# <class 'list'>

# %%
a={1,2,3,4,5}
print(type(a))
# Out:
# <class 'set'>

# %%
a=(2,3,4,5,)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=10,18
print("Value of a is",a)
print(type(a))
# Out:
# Value of a is (10, 18)
# <class 'tuple'>

# %%
a=7
b=18
print("value of a and b are {} and {}". format(a,b))
print("value of a and b are {0} and {1}". format(a,b))
print("value of a and b are {1} and {0}". format(b,a))
print(type(a), type(b))
# Out:
# value of a and b are 7 and 18
# value of a and b are 7 and 18
# value of a and b are 7 and 18
# <class 'int'> <class 'int'>

# %%
print("jersey number of kohli, rohit and dhoni is {1}, {0} and {2}". format(45, 18, 7))
# Out:
# jersey number of kohli, rohit and dhoni is 18, 45 and 7

# %%
print("Today is {3} we are doing this course {1}.\
 As a part of this we are learning {2} with {0}"\
      .format("Hands on training", "Ai ML" , "Python", "thursday"))
# Out:
# Today is thursday we are doing this course Ai ML. As a part of this we are learning Python with Hands on training

# %%
a=input("Enter your marks")
print(a)
print(type(a))
# Out:
# Enter your marks1
# 1
# <class 'str'>

# %%
a=int(input("Enter your marks "))
print(a*0.1)
# Out:
# Enter your marks 89
# 8.9

# %%
a=int(input("Enter a "))
b=int(input("Enter b "))
c=int(input("Enter c "))
print("Product of numbers is". format (a*b*c))
# Out:
# Enter a 3
# Enter b 3
# Enter c 3
# Product of numbers is

# %%
a=(input("Enter your name "))
b=int(input("Enter your age "))
print("My name is {0} and my age after 10 years will be {1}". format (a,b+10))
# Out:
# Enter your name her
# Enter your age 12
# My name is her and my age after 10 years will be 22

# %%
a=str(input("Enter your name "))
b=int(input("Enter your age "))
if(b>=18):
  print("Hi {} you are eligible to vote". format(a))
else:
    print("Hi {} you are not eligible to vote". format(a))
# Out:
# Enter your name Heramba
# Enter your age 17
# Hi Heramba you are not eligible to vote

# %%
a=input('enter ur name')
b=input("enter ur age)
