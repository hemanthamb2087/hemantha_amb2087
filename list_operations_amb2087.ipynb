# %%
p=["neemoil","chrolopyripos","malathion","imidacloprid","spinosad"]
e=[75,85,70,90,88]
x=max(zip(e,p))
print("the most effective pesticide;",x[1])
y=min(zip(e,p))
print("the least effective pesrticide is;",y[1])
z=sum(e)/len(p)
print("average effectiveness percentage is;",z)
for i in zip(e,p):
  if (i[0]>z):
     print("the pesticides above the average is:",i[1])
for i in zip(e,p):
  if (i[0]>80):
     print("pesticides effectiveness above 80 are",i[1])
for i in zip(e,p):
  if (i[0]<80):
     print("pesticides effectiveness below 80 are",len(i))
for i in e:
     print("the effectiveness of all pesticedes after increase  by 5% is",i+5,"%")
for i in zip(e,p):
  if (i[0]>85):
     print("the pesticides suitable for organic farming",i[1])
for i in zip(e,p):
  if (i[0]>75):
     print("these pesticides are not recommended",i[1])
e.sort()
print(e)
# Out:
# the most effective pesticide; imidacloprid
# the least effective pesrticide is; malathion
# average effectiveness percentage is; 81.6
# the pesticides above the average is: chrolopyripos
# the pesticides above the average is: imidacloprid
# the pesticides above the average is: spinosad
# pesticides effectiveness above 80 are chrolopyripos
# pesticides effectiveness above 80 are imidacloprid
# pesticides effectiveness above 80 are spinosad
# pesticides effectiveness below 80 are 2
# pesticides effectiveness below 80 are 2
# the effectiveness of all pesticedes after increase  by 5% is 80 %
# the effectiveness of all pesticedes after increase  by 5% is 90 %
# the effectiveness of all pesticedes after increase  by 5% is 75 %
# the effectiveness of all pesticedes after increase  by 5% is 95 %
# the effectiveness of all pesticedes after increase  by 5% is 93 %
# the pesticides suitable for organic farming imidacloprid
# the pesticides suitable for organic farming spinosad
# ...

# %%
e=["tractor","plough","harvester","seeder","sprayer","thresher"]
c=[850000,25000,1200000,60000,18000,95000]
x=max(zip(c,e))
print("the most expensive equipment;",x[1])
y=min(zip(c,e))
print("the least expensive equipment;",y[1])
a=max(c)
b=min(c)
diff=a-b
print("the difference between the most and least expensive equipment is;",diff)
avg=sum(c)/len(e)
print("the average price of the farm equipment is;",avg)
for i in zip(c,e):
   if (i[0]>avg):
     print("the equipment above the average is:",i[1])
   if (i[0]==avg):
     print("the equipment is equal to average is:",i[1])
   if (i[0]<50000):
     print("the equipment is less than 50000:",i[1])
   if (i[0]>=100000):
     print("the equipment is eligible for goverment subsidy:",i[1])
   if (i[0]>=500000):
     print("the equipment requires loan support:",i[1])
   if (i[0]<75000):
     print("the equipment is suitable for small scale farmers:",i[1])
c.sort()
for i in range(len(c)):
    print(e[i],"-",c[i])
z=sum(c)
print("the TOTAL price of the farm equipment is;",z)
# Out:
# the most expensive equipment; harvester
# the least expensive equipment; sprayer
# the difference between the most and least expensive equipment is; 1182000
# the average price of the farm equipment is; 374666.6666666667
# the equipment above the average is: tractor
# the equipment is eligible for goverment subsidy: tractor
# the equipment requires loan support: tractor
# the equipment is less than 50000: plough
# the equipment is suitable for small scale farmers: plough
# the equipment above the average is: harvester
# the equipment is eligible for goverment subsidy: harvester
# the equipment requires loan support: harvester
# the equipment is suitable for small scale farmers: seeder
# the equipment is less than 50000: sprayer
# the equipment is suitable for small scale farmers: sprayer
# tractor - 18000
# plough - 25000
# harvester - 60000
# seeder - 95000
# sprayer - 850000
# thresher - 1200000
# the TOTAL price of the farm equipment is; 2248000
