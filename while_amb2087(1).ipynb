# %%
i=1
while(i<=5):
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while(i<=5):
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while(i<=20):
  if i%3==0:
   print(i)
  i+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
i=1
while(i<=20):
  if i%3==0 or i%5==0:
    print(i)
  i+=1
# Out:
# 3
# 5
# 6
# 9
# 10
# 12
# 15
# 18
# 20

# %%
i=1
while(i<=20):
  if i%3==0 and i%5==0:
    print(i)
  i+=1
# Out:
# 15

# %%
i=1
while(i<=10):
  if i==6:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while(i<=10):
  if i==6:
    continue
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
