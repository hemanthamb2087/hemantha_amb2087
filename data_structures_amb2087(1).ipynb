# %%
+x=["Rahul","Rohan","Varun"]
y=[20,22,21]
for i in range(len(x)):
  print(x[i],"'s age is", y[i] )
# Out:
# Rahul 's age is 20
# Rohan 's age is 22
# Varun 's age is 21

# %%
x=["Rahul","Rohan","Varun"]
y=[20,22,21]
for n,a in zip(x,y):
  print(n,"'s age is",a)
# Out:
# Rahul 's age is 20
# Rohan 's age is 22
# Varun 's age is 21

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
for i in range(len(x)):
  print("The water requirement of", x[i],"is",y[i],"mm")
# Out:
# The water requirement of Rice is 500 mm
# The water requirement of Wheat is 200 mm
# The water requirement of Millet is 120 mm
# The water requirement of Maize is 150 mm
# The water requirement of Pulses is 190 mm

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
for i,j in zip(x,y):
  print("The water requirement of",i,"is",j,"mm")
# Out:
# The water requirement of Rice is 500 mm
# The water requirement of Wheat is 200 mm
# The water requirement of Millet is 120 mm
# The water requirement of Maize is 150 mm
# The water requirement of Pulses is 190 mm

# %%
x=["First ODI","Second ODI","Third ODI"]
y=[121,110,102]
for i,j in zip(x,y):
  print("Virat's score in the NZ series is:")
  print(i,"-",j)
# Out:
# Virat's score in the NZ series is:
# First ODI - 121
# Virat's score in the NZ series is:
# Second ODI - 110
# Virat's score in the NZ series is:
# Third ODI - 102

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
print("The crops with high water requirement are:")
for i in range(len(x)):
 if y[i]>180:
   print(x[i])
# Out:
# The crops with high water requirement are:
# Rice
# Wheat
# Pulses

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
print("The crops with high water requirement are:")
for i,j in zip(x,y):
  if j>180:
    print(i)
# Out:
# The crops with high water requirement are:
# Rice
# Wheat
# Pulses

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=sum(y)/len(y)
print("Average crop yield:",z,"tonnes/hectare")
# Out:
# Average crop yield: 2.3 tonnes/hectare

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=sum(y)
print("Total crop yield:",z,"tonnes")
# Out:
# Total crop yield: 11.5 tonnes

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
z=max(y)
index=y.index(z)
print("The highest water requirement is:",x[index])
# Out:
# The highest water requirement is: Rice

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[500,200,120,150,190]
z=max(zip(y,x))
print("The highest water requirement is:",z[1])
# Out:
# The highest water requirement is: Rice

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=max(zip(y,x))
print("The highest crop yield is:",z[1])
# Out:
# The highest crop yield is: Maize

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=max(y)
index=y.index(z)
print("The highest crop yield is:",x[index])
# Out:
# The highest crop yield is: Maize

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=sum(y)/len(y)
for i in range(len(x)):
   if y[i]>z:
    print("High yield crops:", x[i])
# Out:
# High yield crops: Rice
# High yield crops: Maize

# %%
x=["Rice","Wheat","Millet","Maize","Pulses"]
y=[2.5,2,1,4,2]
z=sum(y)/len(y)
for i in zip(y,x):
  if i[0]>z:
    print("High yield crops:",i[1])
# Out:
# High yield crops: Rice
# High yield crops: Maize

# %%
x=["Rice","Wheat","Maize","Pulses"]
y=["Urea","DAP","NPK","Compost"]

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
z=max(zip(y,x))
print("The most effective pesticide is",z[1])
v=min(zip(y,x))
print("The least effective pesticide is",v[1])
# Out:
# The most effective pesticide is Imidacloprid
# The least effective pesticide is Malathion

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
w=sum(y)/len(y)
print("The average effectiveness is",w)
print("The pesticides equal or above the average are:")
for i,j in zip(y,x):
  if (i>w):
   print(j)
# Out:
# The average effectiveness is 81.6
# The pesticides equal or above the average are:
# Chlorpyriphos
# Imidacloprid
# Spinosad

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
print("The pesticides with effectiveness above 80% are:")
for i in zip(y,x):
  if i[0]>80:
    print(i[1])

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
updated=[]
for i in range(len(y)):
  if y[i]<75:
    updated.append("Not Recommended")
  else:
    updated.append(x[i])
print(updated)
# Out:
# ['Neem oil', 'Chlorpyriphos', 'Not Recommended', 'Imidacloprid', 'Spinosad']

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
eff=0
print("The number of pesticides with effectiveness less than 80% is:")
for i in zip(y,x):
  if i[0]<80:
   eff=eff+1
print(eff)
# Out:
# The number of pesticides with effectiveness less than 80% is:
# 2

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
print("The updated efficiency of the pesticides are:")
for i in y:
  print(i+5)
# Out:
# The updated efficiency of the pesticides are:
# 80
# 90
# 75
# 95
# 93

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
print("The pesticides suitable for organic farming are:")
for i in zip(y,x):
  if i[0]>85:
    print(i[1])
# Out:
# The pesticides suitable for organic farming are:
# Imidacloprid
# Spinosad

# %%
x=["Neem oil","Chlorpyriphos","Malathion","Imidacloprid","Spinosad"]
y=[75,85,70,90,88]
y.sort()
print("The ascending order of the pesticides based on their effectiveness is:")
for i in range(len(y)):
  print(x[i], "-", y[i])
# Out:
# The ascending order of the pesticides based on their effectiveness is:
# Neem oil - 70
# Chlorpyriphos - 75
# Malathion - 85
# Imidacloprid - 88
# Spinosad - 90

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
z=max(zip(y,x))
print("The most expensive equipment is",z[1])
v=min(zip(y,x))
print("The least expensive equipment is",v[1])
d=max(y)-min(y)
print("The difference in cost between the most expensive and the least expensive equipment is",d)
avg=sum(y)/len(y)
print("The average cost of all the equipments is",round(avg))
t=sum(y)
print("The total cost of all the equipments is",t)
# Out:
# The most expensive equipment is Harvester
# The least expensive equipment is Sprayer
# The difference in cost between the most expensive and the least expensive equipment is 1182000
# The average cost of all the equipments is 374667
# The total cost of all the equipments is 2248000

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
count=0
print("The number of equipments whose cost is less than 500000 is:")
for i in zip(y,x):
   if i[0]<50000:
     count=count+1
print(count)
# Out:
# The number of equipments whose cost is less than 500000 is:
# 2

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
updated=[]
for i in range(len(y)):
  if y[i]>1000000:
   updated.append("High investment")
  else:
    updated.append(x[i])
print(updated)
# Out:
# ['Tractor', 'Plough', 'High investment', 'Seeder', 'Sprayer', 'Thresher']

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
if y==avg:
  print("The equipment equal to the average are")
else:
  print("No equipment is equal to the average cost")
# Out:
# No equipment is equal to the average cost

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
c=y.copy()
c.sort()
for i in zip(c,x):
 print(i[0], "-", i[1])
# Out:
# 18000 - Tractor
# 25000 - Plough
# 60000 - Harvester
# 95000 - Seeder
# 850000 - Sprayer
# 1200000 - Thresher

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
categories=[]
for c in y:
  if c<100000:
    categories.append("Low")
  elif c<=50000:
    categories.apppend("Medium")
  else:
    categories.append("High")
print(categories)
# Out:
# ['High', 'Low', 'High', 'Low', 'Low', 'Low']

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
print("The equipments eligible for govt subsidy are")
for i in zip(y,x):
  if i[0]<=100000:
    print(i[1])
# Out:
# The equipments eligible for govt subsidy are
# Plough
# Seeder
# Sprayer
# Thresher

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
print("The equipment who's cost is above the average is:")
for i in zip(y,x):
 if i[0]>avg:
   print(i[1])
# Out:
# The equipment who's cost is above the average is:
# Tractor
# Harvester

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
print("The equipments that require loan support are:")
for i in zip(y,x):
  if i[0]>500000:
   print(i[1])
# Out:
# The equipments that require loan support are:
# Tractor
# Harvester

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
print("The equipments that are auitable for small scale farmers are:")
for i in zip(y,x):
 if i[0]<75000:
  print(i[1])
# Out:
# The equipments that are auitable for small scale farmers are:
# Plough
# Seeder
# Sprayer

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
print("The equipments after 15% subsidy are:")
for i in zip(y,x):
  if i[0]<=100000:
    print(i[0]-i[0]*0.15,"-",i[1])
# Out:
# The equipments after 15% subsidy are:
# 21250.0 - Plough
# 51000.0 - Seeder
# 15300.0 - Sprayer
# 80750.0 - Thresher

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[850000,25000,1200000,60000,18000,95000]
between=0
print("The number of equipments with cost between 50,000 and 1,00,000 are:")
for i in zip(y,x):
 if i[0]>50000 and i[0]<100000:
   between=between+1
print(between)
# Out:
# The number of equipments with cost between 50,000 and 1,00,000 are:
# 2

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[85000,25000,1200000,60000,18000,95000]
print("The updated cost of equipments after 3% increase is:")
for i in zip(y,x):
   print((i[0]+i[0]*0.03),"-",i[1])
# Out:
# The updated cost of equipments after 3% increase is:
# 87550.0 - Tractor
# 25750.0 - Plough
# 1236000.0 - Harvester
# 61800.0 - Seeder
# 18540.0 - Sprayer
# 97850.0 - Thresher

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[85000,25000,1200000,60000,18000,95000]
print("The equipments which are more than twice the minimum cost are:")
for i in zip(y,x):
  if i[0]>=2*min(y):
   print(i[1])
# Out:
# The equipments which are more than twice the minimum cost are:
# Tractor
# Harvester
# Seeder
# Thresher

# %%
print("The equipments below 1500000 are:")
for i in zip(y,x):
 if i[0]<1500000:
  print(i[1])
# Out:
# The equipments below 1500000 are:
# Tractor
# Plough
# Harvester
# Seeder
# Sprayer
# Thresher

# %%
updated_cost=[]
print( "the cost after increasing 8% is")
for i in y :
    updated_cost.append(round(i*1.08))
print(updated_cost)
# Out:
# the cost after increasing 8% is
# [91800, 27000, 1296000, 64800, 19440, 102600]

# %%
x=["Tractor","Plough","Harvester","Seeder","Sprayer","Thresher"]
y=[85000,25000,1200000,60000,18000,95000]
print("The updated cost of equipments after 8% increase is:")
for i in zip(y,x):
   print((i[0]+i[0]*0.08),"-",i[1])
# Out:
# The updated cost of equipments after 8% increase is:
# 91800.0 - Tractor
# 27000.0 - Plough
# 1296000.0 - Harvester
# 64800.0 - Seeder
# 19440.0 - Sprayer
# 102600.0 - Thresher
