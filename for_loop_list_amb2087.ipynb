# %%
nums=[1,2,3,4]
for i in range(len(nums)):
  nums[i]*=2
print(nums)
# Out:
# [2, 4, 6, 8]

# %%
nums=[1,12,3,4]
for n in nums:
  print(nums)
# Out:
# [1, 12, 3, 4]
# [1, 12, 3, 4]
# [1, 12, 3, 4]
# [1, 12, 3, 4]

# %%
nums=[1,12,3,4]
for n in range(len(nums)):
  print(nums)
# Out:
# [1, 12, 3, 4]
# [1, 12, 3, 4]
# [1, 12, 3, 4]
# [1, 12, 3, 4]

# %%
nums=[1,2,3,4]
squares=[]
for n in range(len(nums)):
  nums[i]=nums[i]**2
  squares.append(nums[i])
print(squares)
# Out:
# [16, 256, 65536, 4294967296]

# %%
nums=[1,2,3,4]
squares=[]
for n in nums:
  squares.append(n**2)
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
nums=[1,2,3,4]
tot=0
for n in nums:
  tot+=n
print(tot)
# Out:
# 10

# %%
nums=[1,2,3,4]
tot=0
for i in range(len(nums)):
  tot+=nums[i]
print(tot)
# Out:
# 10

# %%
nums=[1,2,3,4]
for i in range(len(nums)):
  if nums[i]>3:
    print(nums[i])
# Out:
# 4

# %%
nums=[1,2,3,4]
for n in nums:
  if n>3:
    print(n)
# Out:
# 4
